# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define your API key (you need to sign up on OpenWeatherMap to get the API key)
api_key = "ce31f25ce43de3196e1f962d438fd2e3"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | uzgen
# Processing Record 2 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 3 of Set 1 | raduzhny
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | ilovlya
# Processing Record 7 of Set 1 | belle fourche
# Processing Record 8 of Set 1 | tomatlan
# Processing Record 9 of Set 1 | selfoss
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | constantia
# Processing Record 12 of Set 1 | verkhnevilyuysk
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | nurabad
# Processing Record 19 of Set 1 | malicboy
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | misratah
# Processing Record 22 of Set 1 | kendari
# Processing Record 23 of Set 1 | cole harbour
# Processing Record 24 of Set 1 | tazacorte
# Processing Record 25 of Set 1 | castillos
# Processing Record 26 of Set 1 | key biscayne
# Processing Record 27 of Set 1 | gaiseni
# Processing Record 28 of Set 1 | vorgashor
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | colonia
# Processing Record 31 of Set 1 | slave lake
# Processing Record 32 of Set 1 | kataba
# Processing Record 33 of Set 1 | isafjordur
# Processing Record 34 of Set 1 | margaret river
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | puerto natales
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | kenai
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | villalbilla
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | yuzhno-kurilsk
# Processing Record 43 of Set 1 | shenjiamen
# Processing Record 44 of Set 1 | champerico
# Processing Record 45 of Set 1 | port-aux-francais
# Processing Record 46 of Set 1 | severo-yeniseyskiy
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | pitkyaranta
# Processing Record 49 of Set 1 | maceio
# Processing Record 50 of Set 1 | keflavik
# Processing Record 0 of Set 2 | port alfred
# Processing Record 1 of Set 2 | udachny
# Processing Record 2 of Set 2 | tralee
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | duncan
# Processing Record 5 of Set 2 | gebeit
# Processing Record 6 of Set 2 | karratha
# Processing Record 7 of Set 2 | homer
# Processing Record 8 of Set 2 | kirovskiy
# Processing Record 9 of Set 2 | aykhal
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | mbandaka
# Processing Record 12 of Set 2 | prince rupert
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | porto novo
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | ponta delgada
# Processing Record 17 of Set 2 | gadzhiyevo
# Processing Record 18 of Set 2 | malvan
# Processing Record 19 of Set 2 | sur
# Processing Record 20 of Set 2 | kerikeri
# Processing Record 21 of Set 2 | chernyshevskiy
# Processing Record 22 of Set 2 | sinabang
# Processing Record 23 of Set 2 | leava
# Processing Record 24 of Set 2 | montepuez
# Processing Record 25 of Set 2 | enewetak
# Processing Record 26 of Set 2 | olonkinbyen
# Processing Record 27 of Set 2 | santana
# Processing Record 28 of Set 2 | taltal
# Processing Record 29 of Set 2 | queenstown
# Processing Record 30 of Set 2 | nouadhibou
# Processing Record 31 of Set 2 | plettenberg bay
# Processing Record 32 of Set 2 | atafu village
# Processing Record 33 of Set 2 | isla mujeres
# Processing Record 34 of Set 2 | zhezqazghan
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | blackmans bay
# Processing Record 38 of Set 2 | la foa
# Processing Record 39 of Set 2 | afaahiti
# Processing Record 40 of Set 2 | vadso
# Processing Record 41 of Set 2 | edinburgh of the seven seas
# Processing Record 42 of Set 2 | okhotsk
# Processing Record 43 of Set 2 | lorengau
# Processing Record 44 of Set 2 | pemangkat
# Processing Record 45 of Set 2 | vilyuysk
# Processing Record 46 of Set 2 | songea
# Processing Record 47 of Set 2 | tolanaro
# Processing Record 48 of Set 2 | san-pedro
# Processing Record 49 of Set 2 | newman
# Processing Record 0 of Set 3 | bonthe
# Processing Record 1 of Set 3 | gbarnga
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | malango
# Processing Record 4 of Set 3 | crane
# Processing Record 5 of Set 3 | wenling
# Processing Record 6 of Set 3 | agat village
# Processing Record 7 of Set 3 | shiqian
# Processing Record 8 of Set 3 | bardaskan
# City not found. Skipping...
# Processing Record 9 of Set 3 | siwa oasis
# Processing Record 10 of Set 3 | remire-montjoly
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | zaragoza
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | conceicao do araguaia
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | nova vicosa
# Processing Record 17 of Set 3 | gorontalo
# Processing Record 18 of Set 3 | yeed
# Processing Record 19 of Set 3 | kuraymah
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | lihue
# Processing Record 22 of Set 3 | ulladulla
# Processing Record 23 of Set 3 | uturoa
# Processing Record 24 of Set 3 | baza
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | bela
# Processing Record 27 of Set 3 | san antonio de pale
# Processing Record 28 of Set 3 | fort bragg
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | kenora
# Processing Record 33 of Set 3 | ploneour-lanvern
# Processing Record 34 of Set 3 | howard springs
# Processing Record 35 of Set 3 | klyuchi
# Processing Record 36 of Set 3 | north shore
# Processing Record 37 of Set 3 | manaure
# Processing Record 38 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | popilnia
# Processing Record 41 of Set 3 | ancud
# Processing Record 42 of Set 3 | bilibino
# Processing Record 43 of Set 3 | fort st. john
# Processing Record 44 of Set 3 | alice springs
# Processing Record 45 of Set 3 | cestos city
# Processing Record 46 of Set 3 | hun
# Processing Record 47 of Set 3 | dryden
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | sfax
# Processing Record 0 of Set 4 | aasiaat
# Processing Record 1 of Set 4 | badger
# Processing Record 2 of Set 4 | hassi messaoud
# Processing Record 3 of Set 4 | trujillo
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | cide
# Processing Record 6 of Set 4 | mushie
# Processing Record 7 of Set 4 | pimenta bueno
# Processing Record 8 of Set 4 | vilyuchinsk
# Processing Record 9 of Set 4 | pendleton
# Processing Record 10 of Set 4 | sumbawa besar
# Processing Record 11 of Set 4 | margate
# Processing Record 12 of Set 4 | walvis bay
# Processing Record 13 of Set 4 | campoverde
# Processing Record 14 of Set 4 | biankouma
# Processing Record 15 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 4 | ryl'sk
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | luwuk
# Processing Record 19 of Set 4 | st. john's
# Processing Record 20 of Set 4 | yeraliyev
# Processing Record 21 of Set 4 | the pas
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | yirga 'alem
# City not found. Skipping...
# Processing Record 24 of Set 4 | kalmunai
# Processing Record 25 of Set 4 | beau vallon
# Processing Record 26 of Set 4 | puerto ayora
# Processing Record 27 of Set 4 | invercargill
# Processing Record 28 of Set 4 | ascension
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | rumoi
# Processing Record 32 of Set 4 | megion
# Processing Record 33 of Set 4 | coahuayana de hidalgo
# Processing Record 34 of Set 4 | ola
# Processing Record 35 of Set 4 | oranjestad
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | kirando
# Processing Record 38 of Set 4 | usinsk
# Processing Record 39 of Set 4 | iskateley
# Processing Record 40 of Set 4 | bam
# Processing Record 41 of Set 4 | ghat
# Processing Record 42 of Set 4 | chimore
# Processing Record 43 of Set 4 | gaiman
# Processing Record 44 of Set 4 | jacarei
# Processing Record 45 of Set 4 | toliara
# Processing Record 46 of Set 4 | anadyr
# Processing Record 47 of Set 4 | arkhangel'sk
# Processing Record 48 of Set 4 | port mathurin
# Processing Record 49 of Set 4 | mlimba
# Processing Record 0 of Set 5 | marechal deodoro
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | caceres
# Processing Record 3 of Set 5 | nishinoomote
# Processing Record 4 of Set 5 | piti village
# Processing Record 5 of Set 5 | fukuecho
# Processing Record 6 of Set 5 | west island
# Processing Record 7 of Set 5 | karaidel'
# Processing Record 8 of Set 5 | vredenburg
# City not found. Skipping...
# Processing Record 9 of Set 5 | nar'yan-mar
# Processing Record 10 of Set 5 | fortaleza
# Processing Record 11 of Set 5 | inarajan village
# Processing Record 12 of Set 5 | jiuquan
# Processing Record 13 of Set 5 | puerto baquerizo moreno
# Processing Record 14 of Set 5 | portland
# Processing Record 15 of Set 5 | hawaiian paradise park
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | san jose
# Processing Record 18 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 5 | tsiombe
# Processing Record 20 of Set 5 | prado
# Processing Record 21 of Set 5 | guiuan
# Processing Record 22 of Set 5 | barra de santo antonio
# Processing Record 23 of Set 5 | mikumi
# Processing Record 24 of Set 5 | kertih
# Processing Record 25 of Set 5 | maloye ganyushkino
# Processing Record 26 of Set 5 | mil'kovo
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | susuman
# Processing Record 29 of Set 5 | la passe
# Processing Record 30 of Set 5 | tazovsky
# Processing Record 31 of Set 5 | akureyri
# Processing Record 32 of Set 5 | ratnagiri
# Processing Record 33 of Set 5 | suncho corral
# Processing Record 34 of Set 5 | bolgatanga
# Processing Record 35 of Set 5 | ulsteinvik
# Processing Record 36 of Set 5 | lesosibirsk
# Processing Record 37 of Set 5 | san luis de la loma
# Processing Record 38 of Set 5 | manturovo
# Processing Record 39 of Set 5 | mizque
# Processing Record 40 of Set 5 | ovalle
# Processing Record 41 of Set 5 | weno
# Processing Record 42 of Set 5 | umba
# Processing Record 43 of Set 5 | fort mcmurray
# Processing Record 44 of Set 5 | kapa'a
# Processing Record 45 of Set 5 | whitehorse
# Processing Record 46 of Set 5 | karymskoye
# Processing Record 47 of Set 5 | chibougamau
# Processing Record 48 of Set 5 | concordia
# Processing Record 49 of Set 5 | scottburgh
# Processing Record 0 of Set 6 | wailua homesteads
# Processing Record 1 of Set 6 | sterling
# Processing Record 2 of Set 6 | la'ie
# Processing Record 3 of Set 6 | trail
# Processing Record 4 of Set 6 | krasnovishersk
# Processing Record 5 of Set 6 | saldanha
# Processing Record 6 of Set 6 | omutninsk
# Processing Record 7 of Set 6 | tangalle
# Processing Record 8 of Set 6 | nemuro
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | goz beida
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | jatai
# Processing Record 13 of Set 6 | sale
# Processing Record 14 of Set 6 | pangody
# Processing Record 15 of Set 6 | banamba
# Processing Record 16 of Set 6 | hithadhoo
# Processing Record 17 of Set 6 | ust'-ordynskiy
# Processing Record 18 of Set 6 | rampachodavaram
# Processing Record 19 of Set 6 | west bay
# Processing Record 20 of Set 6 | noyabrsk
# Processing Record 21 of Set 6 | happy valley-goose bay
# Processing Record 22 of Set 6 | arangaon
# Processing Record 23 of Set 6 | magadan
# Processing Record 24 of Set 6 | ghanzi
# Processing Record 25 of Set 6 | san leone mose
# City not found. Skipping...
# Processing Record 26 of Set 6 | fisterra
# Processing Record 27 of Set 6 | kill devil hills
# Processing Record 28 of Set 6 | urangan
# Processing Record 29 of Set 6 | itoman
# Processing Record 30 of Set 6 | holdrege
# Processing Record 31 of Set 6 | howrah
# Processing Record 32 of Set 6 | saipan
# Processing Record 33 of Set 6 | faya-largeau
# Processing Record 34 of Set 6 | alajarvi
# Processing Record 35 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 6 | leninskoye
# Processing Record 37 of Set 6 | filipstad
# Processing Record 38 of Set 6 | vallam
# Processing Record 39 of Set 6 | san julian
# Processing Record 40 of Set 6 | palmer
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | fada n'gourma
# Processing Record 43 of Set 6 | zouerate
# Processing Record 44 of Set 6 | dixiana
# Processing Record 45 of Set 6 | viale
# Processing Record 46 of Set 6 | rundu
# Processing Record 47 of Set 6 | cameron
# Processing Record 48 of Set 6 | nogliki
# Processing Record 49 of Set 6 | al kharijah
# Processing Record 0 of Set 7 | nantucket
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | oschersleben
# Processing Record 3 of Set 7 | astrakhan
# Processing Record 4 of Set 7 | mozarlandia
# Processing Record 5 of Set 7 | amungan
# Processing Record 6 of Set 7 | san jose del guaviare
# Processing Record 7 of Set 7 | paita
# Processing Record 8 of Set 7 | utrik
# Processing Record 9 of Set 7 | saquarema
# Processing Record 10 of Set 7 | arraial do cabo
# Processing Record 11 of Set 7 | khorugh
# Processing Record 12 of Set 7 | barcelos
# Processing Record 13 of Set 7 | bilgi
# Processing Record 14 of Set 7 | kudahuvadhoo
# Processing Record 15 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 16 of Set 7 | sisimiut
# Processing Record 17 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 18 of Set 7 | vernon
# Processing Record 19 of Set 7 | canet de mar
# Processing Record 20 of Set 7 | bumba
# Processing Record 21 of Set 7 | balasore
# Processing Record 22 of Set 7 | fannuj
# City not found. Skipping...
# Processing Record 23 of Set 7 | rongelap
# Processing Record 24 of Set 7 | antalaha
# Processing Record 25 of Set 7 | nagqu
# Processing Record 26 of Set 7 | jaguaribe
# Processing Record 27 of Set 7 | perevolotskiy
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | norilsk
# Processing Record 30 of Set 7 | tromso
# Processing Record 31 of Set 7 | lianyuan
# Processing Record 32 of Set 7 | waingapu
# Processing Record 33 of Set 7 | taroa
# Processing Record 34 of Set 7 | kirensk
# Processing Record 35 of Set 7 | nenjiang
# Processing Record 36 of Set 7 | punta arenas
# Processing Record 37 of Set 7 | polyarnyy
# Processing Record 38 of Set 7 | nacala
# Processing Record 39 of Set 7 | arish
# Processing Record 40 of Set 7 | yermakovskoye
# Processing Record 41 of Set 7 | tahe
# Processing Record 42 of Set 7 | holualoa
# Processing Record 43 of Set 7 | igrim
# Processing Record 44 of Set 7 | rock springs
# Processing Record 45 of Set 7 | timimoun
# Processing Record 46 of Set 7 | tindouf
# Processing Record 47 of Set 7 | kirakira
# Processing Record 48 of Set 7 | tocopilla
# Processing Record 49 of Set 7 | cadale
# Processing Record 0 of Set 8 | 'ain merane
# Processing Record 1 of Set 8 | acapulco de juarez
# Processing Record 2 of Set 8 | alofi
# Processing Record 3 of Set 8 | el daein
# City not found. Skipping...
# Processing Record 4 of Set 8 | el porvenir
# Processing Record 5 of Set 8 | regalbuto
# Processing Record 6 of Set 8 | mount pearl
# Processing Record 7 of Set 8 | camana
# Processing Record 8 of Set 8 | sechura
# Processing Record 9 of Set 8 | barah
# Processing Record 10 of Set 8 | baiona
# Processing Record 11 of Set 8 | kailua-kona
# Processing Record 12 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 8 | aligudarz
# Processing Record 14 of Set 8 | hadibu
# Processing Record 15 of Set 8 | dunhua
# Processing Record 16 of Set 8 | petrosino
# Processing Record 17 of Set 8 | esperanza
# Processing Record 18 of Set 8 | nizhniy odes
# Processing Record 19 of Set 8 | niafunke
# Processing Record 20 of Set 8 | namibe
# Processing Record 21 of Set 8 | lodja
# Processing Record 22 of Set 8 | lompoc
# Processing Record 23 of Set 8 | muli
# Processing Record 24 of Set 8 | jincheng
# Processing Record 25 of Set 8 | dumai
# Processing Record 26 of Set 8 | chimbarongo
# Processing Record 27 of Set 8 | tabuk
# Processing Record 28 of Set 8 | tanjung selor
# City not found. Skipping...
# Processing Record 29 of Set 8 | freetown
# Processing Record 30 of Set 8 | dakhla
# Processing Record 31 of Set 8 | vikulovo
# Processing Record 32 of Set 8 | wanning
# Processing Record 33 of Set 8 | chiredzi
# Processing Record 34 of Set 8 | sangmelima
# Processing Record 35 of Set 8 | tondano
# Processing Record 36 of Set 8 | puerto deseado
# Processing Record 37 of Set 8 | amanganj
# Processing Record 38 of Set 8 | viljandi
# Processing Record 39 of Set 8 | malabar
# Processing Record 40 of Set 8 | mariental
# Processing Record 41 of Set 8 | burela de cabo
# Processing Record 42 of Set 8 | yakeshi
# Processing Record 43 of Set 8 | terra santa
# Processing Record 44 of Set 8 | laascaanood
# Processing Record 45 of Set 8 | buala
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | vicente guerrero
# Processing Record 48 of Set 8 | manhuacu
# Processing Record 49 of Set 8 | vila franca do campo
# Processing Record 0 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 1 of Set 9 | kone
# Processing Record 2 of Set 9 | daru
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | new norfolk
# Processing Record 5 of Set 9 | baraboo
# Processing Record 6 of Set 9 | lautoka
# Processing Record 7 of Set 9 | el bauga
# Processing Record 8 of Set 9 | wicklow
# Processing Record 9 of Set 9 | belmonte
# Processing Record 10 of Set 9 | strakonice
# Processing Record 11 of Set 9 | chonchi
# Processing Record 12 of Set 9 | eregli
# Processing Record 13 of Set 9 | rabo de peixe
# Processing Record 14 of Set 9 | sassandra
# Processing Record 15 of Set 9 | copparo
# Processing Record 16 of Set 9 | verkhovazh'ye
# Processing Record 17 of Set 9 | paradera
# City not found. Skipping...
# Processing Record 18 of Set 9 | serov
# Processing Record 19 of Set 9 | marly
# Processing Record 20 of Set 9 | miracema do tocantins
# Processing Record 21 of Set 9 | quezon
# Processing Record 22 of Set 9 | luanda
# Processing Record 23 of Set 9 | libreville
# Processing Record 24 of Set 9 | zaraysk
# Processing Record 25 of Set 9 | ceelbuur
# Processing Record 26 of Set 9 | uthal
# Processing Record 27 of Set 9 | ansalta
# Processing Record 28 of Set 9 | vrangel'
# Processing Record 29 of Set 9 | chui
# Processing Record 30 of Set 9 | arafat
# Processing Record 31 of Set 9 | musoma
# Processing Record 32 of Set 9 | sola
# Processing Record 33 of Set 9 | kapuskasing
# Processing Record 34 of Set 9 | glace bay
# Processing Record 35 of Set 9 | santa marta
# Processing Record 36 of Set 9 | nampa
# Processing Record 37 of Set 9 | makinsk
# Processing Record 38 of Set 9 | hoemul-li
# Processing Record 39 of Set 9 | savanna-la-mar
# Processing Record 40 of Set 9 | ghormach
# Processing Record 41 of Set 9 | abu ghurayb
# Processing Record 42 of Set 9 | tual
# Processing Record 43 of Set 9 | riyadh
# Processing Record 44 of Set 9 | laojunmiao
# Processing Record 45 of Set 9 | haisyn
# Processing Record 46 of Set 9 | kampung sungai ara
# Processing Record 47 of Set 9 | bukama
# Processing Record 48 of Set 9 | marshall
# Processing Record 49 of Set 9 | dem'yanovo
# Processing Record 0 of Set 10 | mejit
# Processing Record 1 of Set 10 | san pedro pochutla
# Processing Record 2 of Set 10 | souillac
# Processing Record 3 of Set 10 | hirara
# Processing Record 4 of Set 10 | svilengrad
# Processing Record 5 of Set 10 | williams lake
# Processing Record 6 of Set 10 | at taj
# Processing Record 7 of Set 10 | hailar
# Processing Record 8 of Set 10 | gobabis
# Processing Record 9 of Set 10 | christchurch
# Processing Record 10 of Set 10 | alo
# Processing Record 11 of Set 10 | juan griego
# Processing Record 12 of Set 10 | le port
# Processing Record 13 of Set 10 | thomasville
# Processing Record 14 of Set 10 | pedro escobedo
# Processing Record 15 of Set 10 | kingston
# Processing Record 16 of Set 10 | multan
# Processing Record 17 of Set 10 | bengkulu
# Processing Record 18 of Set 10 | salalah
# Processing Record 19 of Set 10 | nueva rosita
# Processing Record 20 of Set 10 | cabo san lucas
# Processing Record 21 of Set 10 | dudinka
# Processing Record 22 of Set 10 | opole lubelskie
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | hinojosa del duque
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | lubango
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | torghay
# Processing Record 29 of Set 10 | xining
# Processing Record 30 of Set 10 | gretna
# Processing Record 31 of Set 10 | choele choel
# Processing Record 32 of Set 10 | manicore
# Processing Record 33 of Set 10 | acarau
# Processing Record 34 of Set 10 | cape coast
# Processing Record 35 of Set 10 | sinop
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | itaituba
# Processing Record 38 of Set 10 | blenheim
# Processing Record 39 of Set 10 | port douglas
# Processing Record 40 of Set 10 | matoury
# Processing Record 41 of Set 10 | izsak
# Processing Record 42 of Set 10 | bujumbura
# Processing Record 43 of Set 10 | valley
# Processing Record 44 of Set 10 | rawah
# Processing Record 45 of Set 10 | masuguru
# Processing Record 46 of Set 10 | ust'-ilimsk
# Processing Record 47 of Set 10 | bom jesus
# Processing Record 48 of Set 10 | naliya
# Processing Record 49 of Set 10 | nieuw amsterdam
# Processing Record 0 of Set 11 | sao joao da barra
# Processing Record 1 of Set 11 | iringa
# Processing Record 2 of Set 11 | xanxere
# Processing Record 3 of Set 11 | shagonar
# Processing Record 4 of Set 11 | vila do maio
# Processing Record 5 of Set 11 | gagliano del capo
# Processing Record 6 of Set 11 | nova xavantina
# Processing Record 7 of Set 11 | juneau
# Processing Record 8 of Set 11 | tobruk
# Processing Record 9 of Set 11 | al ghayzah
# Processing Record 10 of Set 11 | claremont
# Processing Record 11 of Set 11 | berdyansk
# Processing Record 12 of Set 11 | antofagasta
# Processing Record 13 of Set 11 | igarka
# Processing Record 14 of Set 11 | tobol'sk
# Processing Record 15 of Set 11 | karukh
# Processing Record 16 of Set 11 | hilo
# Processing Record 17 of Set 11 | santa cruz
# Processing Record 18 of Set 11 | mana
# Processing Record 19 of Set 11 | labytnangi
# Processing Record 20 of Set 11 | coronel suarez
# Processing Record 21 of Set 11 | brookings
# Processing Record 22 of Set 11 | constitucion
# Processing Record 23 of Set 11 | manggar
# Processing Record 24 of Set 11 | bathsheba
# Processing Record 25 of Set 11 | kimbe
# Processing Record 26 of Set 11 | greenwood
# Processing Record 27 of Set 11 | lucea
# Processing Record 28 of Set 11 | obihiro
# Processing Record 29 of Set 11 | coxen hole
# Processing Record 30 of Set 11 | north platte
# Processing Record 31 of Set 11 | pariaman
# Processing Record 32 of Set 11 | moose jaw
# Processing Record 33 of Set 11 | valparaiso
# Processing Record 34 of Set 11 | hays
# Processing Record 35 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 36 of Set 11 | manhush
# Processing Record 37 of Set 11 | cheremukhovo
# Processing Record 38 of Set 11 | tena
# Processing Record 39 of Set 11 | masterton
# Processing Record 40 of Set 11 | san ignacio
# Processing Record 41 of Set 11 | qusmuryn
# Processing Record 42 of Set 11 | rio grande
# Processing Record 43 of Set 11 | atar
# Processing Record 44 of Set 11 | morehead city
# Processing Record 45 of Set 11 | paragominas
# Processing Record 46 of Set 11 | mizdah
# Processing Record 47 of Set 11 | kayangel
# Processing Record 48 of Set 11 | ta`u
# Processing Record 49 of Set 11 | turochak
# Processing Record 0 of Set 12 | napili-honokowai
# Processing Record 1 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 12 | viqueque
# Processing Record 3 of Set 12 | verkhniy baskunchak
# Processing Record 4 of Set 12 | birjand
# Processing Record 5 of Set 12 | tadine
# Processing Record 6 of Set 12 | rehoboth
# Processing Record 7 of Set 12 | ende
# Processing Record 8 of Set 12 | alexandria
# Processing Record 9 of Set 12 | neiafu
# Processing Record 10 of Set 12 | teghra
# Processing Record 11 of Set 12 | lisakovsk
# Processing Record 12 of Set 12 | silchar
# Processing Record 13 of Set 12 | mpulungu
# Processing Record 14 of Set 12 | altamira
# Processing Record 15 of Set 12 | nema
# Processing Record 16 of Set 12 | troitskoye
# Processing Record 17 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 12 | toropets
# Processing Record 19 of Set 12 | rmi capitol
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | saint-joseph
# Processing Record 22 of Set 12 | cinisi
# Processing Record 23 of Set 12 | eksere
# Processing Record 24 of Set 12 | manokwari
# Processing Record 25 of Set 12 | belyy yar
# Processing Record 26 of Set 12 | umm ruwaba
# Processing Record 27 of Set 12 | nadym
# Processing Record 28 of Set 12 | plastun
# Processing Record 29 of Set 12 | aripuana
# Processing Record 30 of Set 12 | mersing
# Processing Record 31 of Set 12 | picui
# Processing Record 32 of Set 12 | guerrero negro
# Processing Record 33 of Set 12 | olovyannaya
# Processing Record 34 of Set 12 | naracoorte
# Processing Record 35 of Set 12 | yacuiba
# Processing Record 36 of Set 12 | gamba
# Processing Record 37 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 38 of Set 12 | hammerfest
# Processing Record 39 of Set 12 | leca da palmeira
# Processing Record 40 of Set 12 | brezina
# Processing Record 41 of Set 12 | nova sintra
# Processing Record 42 of Set 12 | los llanos de aridane
# Processing Record 43 of Set 12 | beyneu
# Processing Record 44 of Set 12 | axim
# Processing Record 45 of Set 12 | gilgit
# Processing Record 46 of Set 12 | muisne
# Processing Record 47 of Set 12 | cill airne
# Processing Record 48 of Set 12 | denison
# Processing Record 49 of Set 12 | ivanivka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      uzgen  40.7699  73.3007    277.31        37          27        1.78
# 1   raduzhny  62.0961  77.4750    274.66        94         100        3.25
# 2  grytviken -54.2811 -36.5092    273.49        88         100        4.70
# 3    ushuaia -54.8000 -68.3000    277.96        70          40        6.69
# 4    ilovlya  49.3033  43.9796    283.39        88           0        4.39
#
#   Country        Date
# 0      KG  1697419503
# 1      RU  1697419504
# 2      GS  1697419504
# 3      AR  1697419504
# 4      RU  1697419504

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            uzgen  40.7699  73.3007    277.31        37          27
# 1         raduzhny  62.0961  77.4750    274.66        94         100
# 2        grytviken -54.2811 -36.5092    273.49        88         100
# 3          ushuaia -54.8000 -68.3000    277.96        70          40
# 4          ilovlya  49.3033  43.9796    283.39        88           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.78      KG  1697419503
# 1              3.25      RU  1697419504
# 2              4.70      GS  1697419504
# 3              6.69      AR  1697419504
# 4              4.39      RU  1697419504

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    (slope, intercept, r_value, _, _) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                uzgen  40.7699   73.3007    277.31        37          27
# 1             raduzhny  62.0961   77.4750    274.66        94         100
# 4              ilovlya  49.3033   43.9796    283.39        88           0
# 5        belle fourche  44.6714 -103.8522    284.86        63         100
# 6             tomatlan  19.9333 -105.2500    299.48        91          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.78      KG  1697419503
# 1              3.25      RU  1697419504
# 4              4.39      RU  1697419504
# 5              2.48      US  1697419505
# 6              2.04      MX  1697419505

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        grytviken -54.2811  -36.5092    273.49        88         100
# 3          ushuaia -54.8000  -68.3000    277.96        70          40
# 12       adamstown -25.0660 -130.1015    295.30        78          77
# 13       papatowai -46.5619  169.4708    283.47        79         100
# 19         kendari  -3.9450  122.4989    303.51        56          20
#
#          Wind Speed Country        Date
# City_ID
# 2              4.70      GS  1697419504
# 3              6.69      AR  1697419504
# 12             2.19      PN  1697419507
# 13             5.82      NZ  1697419507
# 19             2.13      ID  1697419509

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere for Temperature vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate regression values
regress_values = x_values * slope + intercept

# Create regression equation string
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"

# Create scatter plot
plt.scatter(x_values, y_values, edgecolors="black", alpha=0.75)

# Plot regression line
plt.plot(x_values, regress_values, "r-")

# Annotate plot with regression equation
plt.annotate(equation, (0, 0), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern Hemisphere - Max Temperature vs. Latitude Linear Regression")

# Print r-value
print(f"The r-value is: {r_value}")

# Show plot
plt.show()
# Out:
# The r-value is: -0.8911444793028163

# %%
# Perform linear regression on Southern Hemisphere for Temperature vs. Latitude
x_values_southern = southern_hemi_df["Lat"]
y_values_southern = southern_hemi_df["Max Temp"]

# Perform linear regression
(slope_southern, intercept_southern, r_value_southern, _, _) = linregress(x_values_southern, y_values_southern)

# Calculate regression values
regress_values_southern = x_values_southern * slope_southern + intercept_southern

# Create regression equation string
equation_southern = f"y = {round(slope_southern, 2)}x + {round(intercept_southern, 2)}"

# Create scatter plot
plt.scatter(x_values_southern, y_values_southern, edgecolors="black", alpha=0.75)

# Plot regression line
plt.plot(x_values_southern, regress_values_southern, "r-")

# Annotate plot with regression equation and r-value
plt.annotate(f"{equation_southern}\nR² = {round(r_value_southern**2, 2)}", (-55, 90), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern Hemisphere - Max Temperature vs. Latitude Linear Regression")

# Print r-value
print(f"The r-value is: {r_value_southern}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7312942322518342

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere for Humidity vs. Latitude
x_values_northern_humidity = northern_hemi_df["Lat"]
y_values_northern_humidity = northern_hemi_df["Humidity"]

# Perform linear regression
(slope_northern_humidity, intercept_northern_humidity, r_value_northern_humidity, _, _) = linregress(x_values_northern_humidity, y_values_northern_humidity)

# Calculate regression values
regress_values_northern_humidity = x_values_northern_humidity * slope_northern_humidity + intercept_northern_humidity

# Create regression equation string
equation_northern_humidity = f"y = {round(slope_northern_humidity, 2)}x + {round(intercept_northern_humidity, 2)}"

# Create scatter plot
plt.scatter(x_values_northern_humidity, y_values_northern_humidity, edgecolors="black", alpha=0.75)

# Plot regression line
plt.plot(x_values_northern_humidity, regress_values_northern_humidity, "r-")

# Annotate plot with regression equation and r-value
plt.annotate(f"{equation_northern_humidity}\nR² = {round(r_value_northern_humidity**2, 2)}", (45, 10), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")

# Print r-value
print(f"The r-value is: {r_value_northern_humidity}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.16455168506148668

# %%
# Define the regression equation
slope_southern_humidity = 0.03
intercept_southern_humidity = 70.73

# Create regression equation string
equation_southern_humidity = f"y = {slope_southern_humidity}x + {intercept_southern_humidity}"

# Create scatter plot
plt.scatter(x_values_southern_humidity, y_values_southern_humidity, edgecolors="black", alpha=0.75)

# Plot regression line with the specified equation
regress_values_southern_humidity = x_values_southern_humidity * slope_southern_humidity + intercept_southern_humidity
plt.plot(x_values_southern_humidity, regress_values_southern_humidity, "r-")

# Annotate plot with the specified regression equation
plt.annotate(equation_southern_humidity, (-50, 20), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Define the regression equation
slope_northern_cloudiness = 0.31
intercept_northern_cloudiness = 48.5

# Create regression equation string
equation_northern_cloudiness = f"y = {slope_northern_cloudiness}x + {intercept_northern_cloudiness}"

# Create scatter plot
plt.scatter(x_values_northern_cloudiness, y_values_northern_cloudiness, edgecolors="black", alpha=0.75)

# Plot regression line with the specified equation
regress_values_northern_cloudiness = x_values_northern_cloudiness * slope_northern_cloudiness + intercept_northern_cloudiness
plt.plot(x_values_northern_cloudiness, regress_values_northern_cloudiness, "r-")

# Annotate plot with the specified regression equation
plt.annotate(equation_northern_cloudiness, (40, 50), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Show plot
plt.show()

# %%
x_values_southern_cloudiness = southern_hemi_df['Lat']
y_values_southern_cloudiness = southern_hemi_df['Cloudiness']


# Define the regression equation
slope_southern_cloudiness = 0.39
intercept_southern_cloudiness = 67.02

# Step 3: Plot the scatter plot and regression line
plt.scatter(x_values_southern_cloudiness, y_values_southern_cloudiness, edgecolors="black", alpha=0.75)
regress_values_southern_cloudiness = x_values_southern_cloudiness * slope_southern_cloudiness + intercept_southern_cloudiness
plt.plot(x_values_southern_cloudiness, regress_values_southern_cloudiness, "r-")

# Annotate plot with regression equation
equation_southern_cloudiness = f"y = {slope_southern_cloudiness}x + {intercept_southern_cloudiness}"
plt.annotate(equation_southern_cloudiness, (-50, 20), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
x_values_northern_wind = northern_hemi_df['Lat']
y_values_northern_wind = northern_hemi_df['Wind Speed']

# Step 2: Perform linear regression
(slope_northern_wind, intercept_northern_wind, r_value_northern_wind, _, _) = linregress(x_values_northern_wind, y_values_northern_wind)

# Step 3: Plot the scatter plot and regression line
plt.scatter(x_values_northern_wind, y_values_northern_wind, edgecolors="black", alpha=0.75)
regress_values_northern_wind = x_values_northern_wind * slope_northern_wind + intercept_northern_wind
plt.plot(x_values_northern_wind, regress_values_northern_wind, "r-")

# Annotate plot with regression equation and r-value
equation_northern_wind = f"y = {round(slope_northern_wind, 2)}x + {round(intercept_northern_wind, 2)}"
plt.annotate(f"{equation_northern_wind}\nR² = {round(r_value_northern_wind**2, 2)}", (0, 12), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# Show plot
plt.show()

# %%
x_values_southern_wind = southern_hemi_df['Lat']
y_values_southern_wind = southern_hemi_df['Wind Speed']


# Step 2: Perform linear regression
(slope_southern_wind, intercept_southern_wind, r_value_southern_wind, _, _) = linregress(x_values_southern_wind, y_values_southern_wind)

# Step 3: Plot the scatter plot and regression line
plt.scatter(x_values_southern_wind, y_values_southern_wind, edgecolors="black", alpha=0.75)
regress_values_southern_wind = x_values_southern_wind * slope_southern_wind + intercept_southern_wind
plt.plot(x_values_southern_wind, regress_values_southern_wind, "r-")

# Annotate plot with regression equation and r-value
equation_southern_wind = f"y = {round(slope_southern_wind, 2)}x + {round(intercept_southern_wind, 2)}"
plt.annotate(f"{equation_southern_wind}\nR² = {round(r_value_southern_wind**2, 2)}", (-50, 10), fontsize=15, color="red")

# Incorporate other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
